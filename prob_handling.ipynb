# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('EnergyEfficiency.csv')

# %%
mapping = {0: 'Uniform', 1: 'North', 2: 'East', 3: 'South', 4: 'West'}

df['GlazingAreaDistribution'] = df['GlazingAreaDistribution'].fillna(df['GlazingAreaDistribution'].map(mapping))

df
# Out:
#      Compactness  SurfaceArea  WallArea  RoofArea  Height Orientation  \
# 0           0.98        514.5     294.0    110.25     7.0       North
# 1           0.98        514.5     294.0    110.25     7.0        East
# 2           0.98        514.5     294.0    110.25     7.0       South
# 3           0.98        514.5     294.0    110.25     7.0        West
# 4           0.90        563.5     318.5    122.50     7.0       North
# ..           ...          ...       ...       ...     ...         ...
# 763         0.64        784.0     343.0    220.50     3.5        West
# 764         0.62        808.5     367.5    220.50     3.5       North
# 765         0.62        808.5     367.5    220.50     3.5        East
# 766         0.62        808.5     367.5    220.50     3.5       South
# 767         0.62        808.5     367.5    220.50     3.5        West
#
#      GlazingLevel GlazingAreaDistribution  HeatingLoad  CoolingLoad
# ...
