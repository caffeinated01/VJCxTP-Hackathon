# %%
import pandas as pd
import sklearn

df = pd.read_csv('EnergyEfficiency.csv')

# %%
df = sklearn.utils.shuffle(df)

# %%
df
# Out:
#      Compactness  SurfaceArea  WallArea  RoofArea  Height Orientation  \
# 566         0.66        759.5     318.5    220.50     3.5       South
# 213         0.76        661.5     416.5    122.50     7.0        East
# 389         0.90        563.5     318.5    122.50     7.0        East
# 2           0.98        514.5     294.0    110.25     7.0       South
# 571         0.64        784.0     343.0    220.50     3.5        West
# ..           ...          ...       ...       ...     ...         ...
# 695         0.76        661.5     416.5    122.50     7.0        West
# 613         0.66        759.5     318.5    220.50     3.5        East
# 325         0.66        759.5     318.5    220.50     3.5        East
# 748         0.71        710.5     269.5    220.50     3.5       North
# 68          0.76        661.5     416.5    122.50     7.0       North
#
#      GlazingLevel GlazingAreaDistribution  HeatingLoad  CoolingLoad
# ...
